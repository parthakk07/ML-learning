# %% [markdown]
# <a href="https://colab.research.google.com/github/parthakk07/ML-learning/blob/main/univariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("train.csv")

# %%
df.sample(5)
# Out:
#       PassengerId  Survived  Pclass  \
# 203           204         0       3
# 600           601         1       2
# 345           346         1       2
# 751           752         1       3
# 388           389         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 203                               Youseff, Mr. Gerious    male  45.5      0
# 600  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...  female  24.0      2
# 345                      Brown, Miss. Amelia "Mildred"  female  24.0      0
# 751                                Moor, Master. Meier    male   6.0      0
# 388                               Sadlier, Mr. Matthew    male   NaN      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 203      0    2628   7.2250   NaN        C
# 600      1  243847  27.0000   NaN        S
# 345      0  248733  13.0000   F33        S
# 751      1  392096  12.4750  E121        S
# 388      0  367655   7.7292   NaN        Q

# %% [markdown]
# # categorical data

# %%
sns.countplot(x=df["Survived"])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x=df["Survived"])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x=df["Pclass"])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x=df["Embarked"])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(x=df["Sex"])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df["Survived"].value_counts().plot(kind="pie", autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # numericcal data

# %%
# histogram
plt.hist(df["Fare"])
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["Age"], bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
# distploot
sns.distplot(df["Age"])
# Out:
# /tmp/ipykernel_14566/4237506471.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.histplot(x=df["Age"])
sns.displot(x=df["Age"])

# %%
#  distplot old new is dispplot and histplot
# kde- kernal density estimation tells distribution of data
sns.histplot(df["Age"], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# boxplot gives 5 number summary
sns.boxplot(x=df["Age"])
# Out:
# <Axes: xlabel='Age'>

# %%
print(df["Age"].min())
print(df["Age"].max())
print(df["Age"].mean())
# Out:
# 0.42
# 80.0
# 29.69911764705882
