# %% [markdown]
# <a href="https://colab.research.google.com/github/parthakk07/ML-learning/blob/main/multivariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pandas.core.reshape.pivot import crosstab

# %%
titanic = pd.read_csv("train.csv")
titanic.sample(5)
# Out:
#       PassengerId  Survived  Pclass  \
# 371           372         0       3
# 625           626         0       1
# 234           235         0       2
# 343           344         0       2
# 457           458         1       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 371                   Wiklund, Mr. Jakob Alfred    male  18.0      1      0
# 625                       Sutton, Mr. Frederick    male  61.0      0      0
# 234           Leyson, Mr. Robert William Norman    male  24.0      0      0
# 343  Sedgwick, Mr. Charles Frederick Waddington    male  25.0      0      0
# 457           Kenyon, Mrs. Frederick R (Marion)  female   NaN      1      0
#
#          Ticket     Fare Cabin Embarked
# 371     3101267   6.4958   NaN        S
# 625       36963  32.3208   D50        S
# 234  C.A. 29566  10.5000   NaN        S
# 343      244361  13.0000   NaN        S
# 457       17464  51.8625   D21        S

# %%
tips = sns.load_dataset("tips")
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 168       10.59  1.61  Female    Yes  Sat  Dinner     2
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2
# 30         9.55  1.45    Male     No  Sat  Dinner     2
# 47        32.40  6.00    Male     No  Sun  Dinner     4
# 229       22.12  2.88  Female    Yes  Sat  Dinner     2

# %%
flight = sns.load_dataset("flights")
flight.sample(5)
# Out:
#     year month  passengers
# 26  1951   Mar         178
# 64  1954   May         234
# 34  1951   Nov         146
# 24  1951   Jan         145
# 0   1949   Jan         112

# %%
iris = sns.load_dataset("iris")
iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 75            6.6          3.0           4.4          1.4  versicolor
# 111           6.4          2.7           5.3          1.9   virginica
# 7             5.0          3.4           1.5          0.2      setosa
# 30            4.8          3.1           1.6          0.2      setosa
# 143           6.8          3.2           5.9          2.3   virginica

# %%
# numerical - numerical
sns.scatterplot(x=tips["total_bill"], y=tips["tip"], size=tips["size"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(
    x=tips["total_bill"],
    y=tips["tip"],
    size=tips["size"],
    hue=tips["sex"],
    style=tips["smoker"],
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # categorical an dnumerical

# %%
sns.barplot(x=titanic["Pclass"], y=titanic["Age"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x=titanic["Pclass"], y=titanic["Fare"], hue=titanic["Sex"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# # box plot

# %%
sns.boxplot(x=titanic["Sex"], y=titanic["Age"])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x=titanic["Sex"], y=titanic["Age"], hue=titanic["Survived"])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # displot

# %%
sns.displot(x=titanic[titanic["Survived"] == 0]["Age"], kde=True)
sns.displot(x=titanic[titanic["Survived"] == 1]["Age"], kde=True)

# %%
sns.displot(x=titanic["Age"], hue=titanic["Survived"], kde=True)

# %%
sns.displot(x=titanic["Age"], hue=titanic["Survived"], kind="kde", fill=True)

# %% [markdown]
# # categrocial - categorical

# %%
pd.crosstab(titanic["Pclass"], titanic["Survived"])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(titanic["Pclass"], titanic["Survived"]))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby("Pclass")["Survived"].mean() * 100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
titanic.groupby("Sex")["Survived"].mean() * 100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
sns.clustermap(pd.crosstab(titanic["SibSp"], titanic["Survived"]))

# %% [markdown]
# # pairpot

# %%
sns.pairplot(iris, hue="species")

# %%
new = flight.groupby("year")["passengers"].sum().reset_index()

# %%
sns.lineplot(x=new["year"], y=new["passengers"])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flight.pivot_table(values="passengers", index="month", columns="year")
# Out:
# /tmp/ipykernel_1792/2698000333.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flight.pivot_table(values="passengers", index="month", columns="year")
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# Dec    118.0  140.0  166.0  194.0  201.0  229.0  278.0  306.0  336.0  337.0
#
# year    1959   1960
# month
# Jan    360.0  417.0
# Feb    342.0  391.0
# Mar    406.0  419.0
# Apr    396.0  461.0
# May    420.0  472.0
# Jun    472.0  535.0
# Jul    548.0  622.0
# Aug    559.0  606.0
# Sep    463.0  508.0
# Oct    407.0  461.0
# Nov    362.0  390.0
# Dec    405.0  432.0

# %%
sns.heatmap(flight.pivot_table(values="passengers", index="month", columns="year"))
# Out:
# /tmp/ipykernel_1792/1950466640.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flight.pivot_table(values="passengers", index="month", columns="year"))
# <Axes: xlabel='year', ylabel='month'>
