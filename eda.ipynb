# %% [markdown]
# <a href="https://colab.research.google.com/github/parthakk07/ML-learning/blob/main/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("genz_college_admission_prediction.csv")
df.sample(5)
# Out:
#         student_id   age  gender           state  family_income  \
# 47204        47205  22.0    Male  North Carolina       142513.0
# 236291      236292  22.0  Female        Virginia        59119.0
# 277512      277513  16.0  Female      Washington       101717.0
# 249062      249063  20.0  Female  North Carolina        69274.0
# 214925      214926  17.0  Female            Ohio        77861.0
#
#         high_school_gpa  sat_score  act_score  attendance_rate  ap_courses  \
# 47204              3.88     1180.0       22.0             98.4         1.0
# 236291             3.21      982.0       14.0             94.4         5.0
# 277512             4.00     1008.0       25.0             95.9         1.0
# 249062             3.86     1210.0       25.0             96.3         3.0
# 214925             2.99     1030.0       24.0             85.0         6.0
#
#         extracurricular_count  volunteer_hours  leadership_positions  \
# 47204                     2.0            150.0                   1.0
# 236291                    3.0            117.0                   1.0
# 277512                    6.0             83.0                   3.0
# 249062                    3.0             29.0                   2.0
# 214925                    5.0             89.0                   2.0
#
#         coding_projects  social_media_hours  online_certifications  \
# 47204               1.0                 4.3                    0.0
# 236291              3.0                 5.4                    4.0
# 277512              3.0                 5.2                    1.0
# 249062              0.0                 5.2                    0.0
# 214925              4.0                 3.1                    3.0
#
#         essay_score  recommendation_score  interview_score  admission_status
# 47204          47.8                  80.6             43.5               1.0
# 236291         68.5                  70.5             71.8               1.0
# 277512         59.4                  80.8             98.2               1.0
# 249062         92.5                  69.0             71.4               1.0
# 214925         65.9                  56.3             86.3               1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403579 entries, 0 to 403578
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   student_id             403579 non-null  int64
#  1   age                    403578 non-null  float64
#  2   gender                 403578 non-null  object
#  3   state                  403578 non-null  object
#  4   family_income          403578 non-null  float64
#  5   high_school_gpa        403578 non-null  float64
#  6   sat_score              403578 non-null  float64
#  7   act_score              403578 non-null  float64
#  8   attendance_rate        403578 non-null  float64
#  9   ap_courses             403578 non-null  float64
#  10  extracurricular_count  403578 non-null  float64
#  11  volunteer_hours        403578 non-null  float64
#  12  leadership_positions   403578 non-null  float64
#  13  coding_projects        403578 non-null  float64
#  14  social_media_hours     403578 non-null  float64
#  15  online_certifications  403578 non-null  float64
#  16  essay_score            403578 non-null  float64
#  17  recommendation_score   403578 non-null  float64
#  18  interview_score        403578 non-null  float64
#  19  admission_status       403578 non-null  float64
# dtypes: float64(17), int64(1), object(2)
# memory usage: 61.6+ MB

# %%
df.isnull().sum()
# Out:
# student_id               0
# age                      1
# gender                   1
# state                    1
# family_income            1
# high_school_gpa          1
# sat_score                1
# act_score                1
# attendance_rate          1
# ap_courses               1
# extracurricular_count    1
# volunteer_hours          1
# leadership_positions     1
# coding_projects          1
# social_media_hours       1
# online_certifications    1
# essay_score              1
# recommendation_score     1
# interview_score          1
# admission_status         1
# dtype: int64

# %%
df.describe()
# Out:
#           student_id            age  family_income  high_school_gpa  \
# count  403579.000000  403578.000000  403578.000000    403578.000000
# mean   201789.000999      18.998905   71644.900123         3.189411
# std    116503.364754       2.000194   47037.502330         0.475777
# min         1.000000      16.000000    2124.000000         0.920000
# 25%    100894.500000      17.000000   39995.000000         2.860000
# 50%    201789.000000      19.000000   59905.000000         3.200000
# 75%    302683.500000      21.000000   89629.750000         3.540000
# max    403578.000000      22.000000  929368.000000         4.000000
#
#            sat_score      act_score  attendance_rate     ap_courses  \
# count  403578.000000  403578.000000    403578.000000  403578.000000
# mean     1099.382533      23.479189        91.746829       2.997034
# std       217.172827       5.911030         5.530411       1.727516
# min       400.000000       1.000000        63.200000       0.000000
# 25%       952.000000      19.000000        87.900000       2.000000
# 50%      1101.000000      24.000000        92.000000       3.000000
# 75%      1248.000000      28.000000        96.000000       4.000000
# max      1600.000000      36.000000       100.000000      12.000000
#
#        extracurricular_count  volunteer_hours  leadership_positions  \
# count          403578.000000    403578.000000         403578.000000
# mean                3.998122        99.392467              1.202803
# std                 1.999906        49.972342              1.095569
# min                 0.000000         2.000000              0.000000
# 25%                 3.000000        63.000000              0.000000
# 50%                 4.000000        91.000000              1.000000
# 75%                 5.000000       127.000000              2.000000
# max                15.000000       504.000000              8.000000
#
#        coding_projects  social_media_hours  online_certifications  \
# count    403578.000000       403578.000000          403578.000000
# mean          2.001541            4.502667               1.997089
# std           1.416303            1.788700               1.415082
# min           0.000000            0.000000               0.000000
# 25%           1.000000            3.300000               1.000000
# 50%           2.000000            4.500000               2.000000
# 75%           3.000000            5.700000               3.000000
# max          11.000000           12.900000              12.000000
#
#          essay_score  recommendation_score  interview_score  admission_status
# count  403578.000000         403578.000000    403578.000000     403578.000000
# mean       74.908591             77.962211        72.753741          0.882003
# std        11.799457              9.888184        14.517828          0.322605
# min        21.700000             28.800000         8.500000          0.000000
# 25%        66.900000             71.200000        62.800000          1.000000
# 50%        75.000000             78.000000        72.900000          1.000000
# 75%        83.100000             84.800000        83.100000          1.000000
# max       100.000000            100.000000       100.000000          1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.1, random_state=42)

# %%
train.to_csv("train.csv", index=False)
test.to_csv("test.csv", index=False)

# %%
df = pd.read_csv("test.csv")

# %%
df.shape
# Out:
# (40358, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40358 entries, 0 to 40357
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             40358 non-null  int64
#  1   age                    40358 non-null  float64
#  2   gender                 40358 non-null  object
#  3   state                  40358 non-null  object
#  4   family_income          40358 non-null  float64
#  5   high_school_gpa        40358 non-null  float64
#  6   sat_score              40358 non-null  float64
#  7   act_score              40358 non-null  float64
#  8   attendance_rate        40358 non-null  float64
#  9   ap_courses             40358 non-null  float64
#  10  extracurricular_count  40358 non-null  float64
#  11  volunteer_hours        40358 non-null  float64
#  12  leadership_positions   40358 non-null  float64
#  13  coding_projects        40358 non-null  float64
#  14  social_media_hours     40358 non-null  float64
#  15  online_certifications  40358 non-null  float64
#  16  essay_score            40358 non-null  float64
#  17  recommendation_score   40358 non-null  float64
#  18  interview_score        40358 non-null  float64
#  19  admission_status       40358 non-null  float64
# dtypes: float64(17), int64(1), object(2)
# memory usage: 6.2+ MB

# %%
df.describe()
# Out:
#           student_id           age  family_income  high_school_gpa  \
# count   40358.000000  40358.000000   40358.000000     40358.000000
# mean   201436.193939     19.000966   71690.400367         3.185355
# std    116615.736097      2.007413   47210.117140         0.478011
# min        25.000000     16.000000    4467.000000         1.080000
# 25%    100151.000000     17.000000   40206.250000         2.860000
# 50%    200340.000000     19.000000   59943.500000         3.200000
# 75%    303208.500000     21.000000   89519.750000         3.540000
# max    403577.000000     22.000000  696327.000000         4.000000
#
#           sat_score     act_score  attendance_rate    ap_courses  \
# count  40358.000000  40358.000000     40358.000000  40358.000000
# mean    1100.589053     23.521483        91.739063      3.000545
# std      217.100908      5.891182         5.535952      1.723381
# min      400.000000      1.000000        66.800000      0.000000
# 25%      953.000000     20.000000        88.000000      2.000000
# 50%     1102.000000     24.000000        92.000000      3.000000
# 75%     1248.000000     28.000000        96.100000      4.000000
# max     1600.000000     36.000000       100.000000     12.000000
#
#        extracurricular_count  volunteer_hours  leadership_positions  \
# count           40358.000000     40358.000000          40358.000000
# mean                4.012909        99.177809              1.202314
# std                 2.013350        50.025040              1.090170
# min                 0.000000         3.000000              0.000000
# 25%                 3.000000        63.000000              0.000000
# 50%                 4.000000        91.000000              1.000000
# 75%                 5.000000       127.000000              2.000000
# max                15.000000       478.000000              8.000000
#
#        coding_projects  social_media_hours  online_certifications  \
# count     40358.000000        40358.000000           40358.000000
# mean          1.993855            4.496947               1.983324
# std           1.418679            1.790630               1.411792
# min           0.000000            0.000000               0.000000
# 25%           1.000000            3.300000               1.000000
# 50%           2.000000            4.500000               2.000000
# 75%           3.000000            5.700000               3.000000
# max          10.000000           11.500000              11.000000
#
#         essay_score  recommendation_score  interview_score  admission_status
# count  40358.000000          40358.000000     40358.000000      40358.000000
# mean      74.922855             77.975948        72.915925          0.880049
# std       11.722070              9.867234        14.453288          0.324909
# min       25.000000             37.300000        12.600000          0.000000
# 25%       66.900000             71.200000        63.100000          1.000000
# 50%       75.000000             78.000000        73.100000          1.000000
# 75%       83.000000             84.800000        83.200000          1.000000
# max      100.000000            100.000000       100.000000          1.000000

# %%
df.isnull().sum()
# Out:
# student_id               0
# age                      0
# gender                   0
# state                    0
# family_income            0
# high_school_gpa          0
# sat_score                0
# act_score                0
# attendance_rate          0
# ap_courses               0
# extracurricular_count    0
# volunteer_hours          0
# leadership_positions     0
# coding_projects          0
# social_media_hours       0
# online_certifications    0
# essay_score              0
# recommendation_score     0
# interview_score          0
# admission_status         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# univariate analysis
#  categorical column
sns.countplot(x=df["admission_status"])
# Out:
# <Axes: xlabel='admission_status', ylabel='count'>

# %%
df["admission_status"].value_counts().plot(kind="pie", autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["gender"].value_counts().plot(kind="pie", autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x=df["leadership_positions"])
# Out:
# <Axes: xlabel='leadership_positions', ylabel='count'>

# %%
df["leadership_positions"].value_counts().plot(kind="pie", autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
# numerical columns
sns.histplot(x=df["age"], kde=True)
df["age"].skew()
# Out:
# np.float64(-0.0009571776177330362)

# %%
sns.displot(x=df["age"])

# %%
sns.boxplot(x=df["age"])
# Out:
# <Axes: xlabel='age'>

# %%
sns.histplot(x=df["state"])
# Out:
# <Axes: xlabel='state', ylabel='Count'>

# %%
sns.countplot(x=df["state"])
# Out:
# <Axes: xlabel='state', ylabel='count'>

# %%
sns.displot(x=df["family_income"], kde=True)
df["family_income"].skew()
# Out:
# np.float64(2.259246088213956)

# %%
sns.boxplot(x=df["family_income"])
# Out:
# <Axes: xlabel='family_income'>

# %%
sns.displot(x=df["high_school_gpa"], kde=True)
df["high_school_gpa"].skew()
# Out:
# np.float64(-0.2596178378429313)

# %%
sns.displot(x=df["sat_score"])
df["sat_score"].skew()
# Out:
# np.float64(-0.06659176178132416)

# %%
sns.displot(x=df["act_score"], kde=True)
df["act_score"].mean()
df["act_score"].skew()
# Out:
# np.float64(-0.09653901935902122)

# %%
sns.displot(x=df["attendance_rate"], kde=True)

# %%
sns.displot(x=df["ap_courses"])

# %%
sns.boxplot(x=df["ap_courses"])
# Out:
# <Axes: xlabel='ap_courses'>

# %%
sns.displot(x=df["extracurricular_count"], kde=True)
df["extracurricular_count"].skew()
# Out:
# np.float64(0.5139586003637275)

# %%
sns.boxplot(x=df["extracurricular_count"])
# Out:
# <Axes: xlabel='extracurricular_count'>

# %%
sns.displot(x=df["volunteer_hours"], kde=True)

# %%
sns.boxplot(x=df["volunteer_hours"])
# Out:
# <Axes: xlabel='volunteer_hours'>

# %%
sns.displot(x=df["coding_projects"])

# %%
sns.boxplot(x=df["coding_projects"])
# Out:
# <Axes: xlabel='coding_projects'>

# %%
sns.displot(x=df["social_media_hours"], kde=True)

# %%
sns.boxplot(x=df["social_media_hours"])
# Out:
# <Axes: xlabel='social_media_hours'>

# %%
sns.displot(x=df["online_certifications"], kde=True)

# %%
sns.countplot(x=df["online_certifications"])
# Out:
# <Axes: xlabel='online_certifications', ylabel='count'>

# %%
sns.displot(x=df["essay_score"], kde=True)

# %%
sns.histplot(x=df["essay_score"], kde=True)
# Out:
# <Axes: xlabel='essay_score', ylabel='Count'>

# %%
sns.boxplot(x=df["essay_score"])
# Out:
# <Axes: xlabel='essay_score'>

# %%
sns.displot(x=df["recommendation_score"])

# %%
sns.boxplot(x=df["recommendation_score"])
# Out:
# <Axes: xlabel='recommendation_score'>

# %%
sns.boxplot(x=df["interview_score"])
# Out:
# <Axes: xlabel='interview_score'>

# %%
sns.histplot(x=df["interview_score"], kde=True)
# Out:
# <Axes: xlabel='interview_score', ylabel='Count'>

# %%
# multivarite analysis
